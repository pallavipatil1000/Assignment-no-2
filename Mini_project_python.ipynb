# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavipatil1000/Assignment-no-2/blob/main/Mini_project_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import string

length = int(input("Enter password length: "))

characters = string.ascii_letters + string.digits + string.punctuation

password = ""

for i in range(length):
    password += random.choice(characters)

print("Generated Password:", password)
# Out:
# Enter password length: 8
# Generated Password: nb(f*s9/
