# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavipatil1000/Assignment-no-2/blob/main/Assignment%20no.%203jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b and a > c:
    print("Greatest number is", a)
elif b > c:
    print("Greatest number is", b)
else:
    print("Greatest number is", c)
# Out:
# Enter first number: 10
# Enter second number: 5
# Enter third number: 20
# Greatest number is 20

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter a number: 20
# Even number

# %%
x = input("Enter something: ")

if x.isdigit():
    print("It is a Number")
else:
    print("It is a Character")
# Out:
# Enter something: A
# It is a Character
