# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavipatil1000/Assignment-no-2/blob/main/Assignment%20no.%202jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 3.5

# Casting
c = float(a)
d = int(b)

print("Integer value:", a)
print("After converting to float:", c)

print("Float value:", b)
print("After converting to integer:", d)

# Logical operators example

a = 10
b = 5

print("AND operator:", a > 5 and b > 2)
print("OR operator:", a > 5 or b > 10)
print("NOT operator:", not(a > 5))
# Out:
# Integer value: 10
# After converting to float: 10.0
# Float value: 3.5
# After converting to integer: 3
# AND operator: True
# OR operator: True
# NOT operator: False
