# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavipatil1000/Assignment-no-2/blob/main/Assignment%20no.5%20jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=min(10,1,12,18,45,78,96)
y=max(10,1,12,18,45,78,96)
print(x)
print(y)
x=abs(-3)
print(x)
z=pow(2,12)
print(z)
import math
x=math.sqrt(144)
print(x)
x=math.pi
print(x)
# Out:
# 1
# 96
# 3
# 4096
# 12.0
# 3.141592653589793
