# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavipatil1000/Assignment-no-2/blob/main/Assignment_no_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A=(input("length of string"))
print(A)

a=input("enter 1st string")
b=input("enter 2nd string")
c=a+b
print(c)

A="Pallavi"
B="Patil"
C=A+B
print(C)
# Out:
# length of string25
# 25
# enter 1st string20
# enter 2nd string30
# 2030
# PallaviPatil
